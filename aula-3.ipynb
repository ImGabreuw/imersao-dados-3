# %%
# Código da aula 2

import pandas as pd

url_dados = "https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true"

dados = pd.read_csv(url_dados, compression = "zip")

mapa = {"droga": "composto"}
dados.rename(columns = mapa, inplace = True)

dados
# Out:
#                  id    tratamento  tempo dose   composto     g-0     g-1  \
# 0      id_000644bb2     com_droga     24   D1  b68db1d53  1.0620  0.5577
# 1      id_000779bfc     com_droga     72   D1  df89a8e5a  0.0743  0.4087
# 2      id_000a6266a     com_droga     48   D1  18bb41b2c  0.6280  0.5817
# 3      id_0015fd391     com_droga     48   D1  8c7f86626 -0.5138 -0.2491
# 4      id_001626bd3     com_droga     72   D2  7cbed3131 -0.3254 -0.4009
# ...             ...           ...    ...  ...        ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  df1d0a5a1  0.1394 -0.0636
# 23810  id_fffb70c0c     com_droga     24   D2  ecf3b6b74 -1.3260  0.3478
# 23811  id_fffc1c3f4  com_controle     48   D2  cacb2b860  0.3942  0.3756
# 23812  id_fffcb9e7c     com_droga     24   D1  8b87a7a83  0.6660  0.2324
# 23813  id_ffffdd77b     com_droga     72   D1  972f41291 -0.8598  1.0240
#
#           g-2     g-3     g-4  ...    c-90    c-91    c-92    c-93    c-94  \
# ...

# %%
dados.head()
# Out:
#              id tratamento  tempo dose   composto     g-0     g-1     g-2  \
# 0  id_000644bb2  com_droga     24   D1  b68db1d53  1.0620  0.5577 -0.2479
# 1  id_000779bfc  com_droga     72   D1  df89a8e5a  0.0743  0.4087  0.2991
# 2  id_000a6266a  com_droga     48   D1  18bb41b2c  0.6280  0.5817  1.5540
# 3  id_0015fd391  com_droga     48   D1  8c7f86626 -0.5138 -0.2491 -0.2656
# 4  id_001626bd3  com_droga     72   D2  7cbed3131 -0.3254 -0.4009  0.9700
#
#       g-3     g-4  ...    c-90    c-91    c-92    c-93    c-94    c-95  \
# 0 -0.6208 -0.1944  ...  0.2862  0.2584  0.8076  0.5523 -0.1912  0.6584
# 1  0.0604  1.0190  ... -0.4265  0.7543  0.4708  0.0230  0.2957  0.4899
# 2 -0.0764 -0.0323  ... -0.7250 -0.6297  0.6103  0.0223 -1.3240 -0.3174
# 3  0.5288  4.0620  ... -2.0990 -0.6441 -5.6300 -1.3780 -0.8632 -1.2880
# 4  0.6919  1.4180  ...  0.0042  0.0048  0.6670  1.0690  0.5523 -0.3031
#
#      c-96    c-97    c-98    c-99
# 0 -0.3981  0.2139  0.3801  0.4176
# ...

# %%
# Documentação: https://pandas.pydata.org/docs/reference/api/pandas.crosstab.html?highlight=frequency%20table
pd.crosstab(dados["dose"], dados["tempo"])
# Out:
# tempo    24    48    72
# dose
# D1     3886  4354  3907
# D2     3886  3896  3885

# %%
pd.crosstab([dados["dose"], dados["tempo"]], dados["tratamento"])
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24              301       3585
#      48              343       4011
#      72              307       3600
# D2   24              305       3581
#      48              305       3591
#      72              305       3580

# %%
pd.crosstab([dados["dose"], dados["tempo"]], dados["tratamento"], normalize = True)
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.012640   0.150542
#      48         0.014403   0.168430
#      72         0.012892   0.151172
# D2   24         0.012808   0.150374
#      48         0.012808   0.150794
#      72         0.012808   0.150332

# %%
pd.crosstab([dados["dose"], dados["tempo"]], dados["tratamento"], normalize = "index")
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.077458   0.922542
#      48         0.078778   0.921222
#      72         0.078577   0.921423
# D2   24         0.078487   0.921513
#      48         0.078285   0.921715
#      72         0.078507   0.921493

# %%
# values = recortar uma coluna
# aggfunc = agregar uma função a um valores

pd.crosstab(
    [dados["dose"], dados["tempo"]], 
    dados["tratamento"], 
    values = dados["g-0"], 
    aggfunc = "mean"
)
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24        -0.251760   0.367996
#      48        -0.122773   0.412469
#      72        -0.295271   0.286250
# D2   24         0.010754   0.115253
#      48         0.013174   0.214480
#      72         0.070250   0.253439

# %%
dados[["g-0", "g-3"]]
# Out:
#           g-0     g-3
# 0      1.0620 -0.6208
# 1      0.0743  0.0604
# 2      0.6280 -0.0764
# 3     -0.5138  0.5288
# 4     -0.3254  0.6919
# ...       ...     ...
# 23809  0.1394 -0.5080
# 23810 -1.3260  0.9905
# 23811  0.3942 -0.7389
# 23812  0.6660  0.2044
# 23813 -0.8598  0.7952
#
# [23814 rows x 2 columns]

# %%
dados[["g-0", "g-3"]]
# Out:
#           g-0     g-3
# 0      1.0620 -0.6208
# 1      0.0743  0.0604
# 2      0.6280 -0.0764
# 3     -0.5138  0.5288
# 4     -0.3254  0.6919
# ...       ...     ...
# 23809  0.1394 -0.5080
# 23810 -1.3260  0.9905
# 23811  0.3942 -0.7389
# 23812  0.6660  0.2044
# 23813 -0.8598  0.7952
#
# [23814 rows x 2 columns]

# %%
import seaborn as sns

sns.scatterplot(x = "g-0", y = "g-3", data = dados)

# Cada ponto corresponde a uma linha da tabela (plano cartesiano)
# Out:
# <AxesSubplot:xlabel='g-0', ylabel='g-3'>

# %%
sns.scatterplot(x = "g-0", y = "g-8", data = dados)
# Out:
# <AxesSubplot:xlabel='g-0', ylabel='g-8'>

# %%
# scatterplot + linhas mostrando a média dos pontos

sns.lmplot(data = dados, x = "g-0", y = "g-8", line_kws = {"color": "red"})

# %%
sns.lmplot(data = dados, x = "g-0", y = "g-8", line_kws = {"color": "red"}, col = "tratamento")

# %%
sns.lmplot(data = dados, x = "g-0", y = "g-8", line_kws = {"color": "red"}, col = "tratamento", row = "tempo")

# %%
# Correlação entre as colunas

corr = dados.loc[:, "g-0":"g-50"].corr()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Gere uma máscara para o triângulo superior
mask = np.triu(np.ones_like(corr, dtype = bool))

# Configure a figura matplotlib
f, ax = plt.subplots(figsize = (11, 9))

# Gerar um mapa de cores divergentes personalizado
cmap = sns.diverging_palette(230, 20, as_cmap = True)

# Desenhe o mapa de calor com a máscara e a proporção correta
sns.heatmap(corr, mask = mask, cmap = cmap, center = 0, square = True, linewidths = .5, cbar_kws = {"shrink": .5})
# Out:
# <AxesSubplot:>

# %%
corr_celulas = dados.loc[:, "c-0":"c-50"].corr()

# %%
mask = np.triu(np.ones_like(corr_celulas, dtype = bool))

f, ax = plt.subplots(figsize = (11, 9))

cmap = sns.diverging_palette(230, 20, as_cmap = True)

sns.heatmap(corr_celulas, mask = mask, cmap = cmap, center = 0, square = True, linewidths = .5, cbar_kws = {"shrink": .5})
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Desafio 1: Criar tabelas de frequência com `pandas.groupby()`.

# %% [markdown]
# ### Desafio 2: Normalizar o crosstab pela coluna.

# %% [markdown]
# ### Desafio 3: Explorar outros agregadores.

# %% [markdown]
# ### Desafio 4: Explorar o `melt`.

# %% [markdown]
# ### Desafio 5: Calcular e analisar a correlação entre G e C.

# %% [markdown]
# ### Desafio : Refletir sobre os efeitos biológicos

# %% [markdown]
# ### Desafio 7: Estudar o código que plota a matriz de correlação (heatmap).

# %% [markdown]
# ### Desafio 8: Resumo da aula
#
# * correlação entre tabelas com crosstab
# * scatterplot
# * lmplot
# * heatmap
